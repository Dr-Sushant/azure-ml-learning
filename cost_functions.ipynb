# %%
# Step 1: core libraries + optimizer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from m0b_optimizer import MyOptimizer

# Step 2: (optional) bring back previously trained model for continuity
import joblib, os
model_path = os.path.join(os.getcwd(), 'outputs', 'linear_regression_model.pkl')
if os.path.exists(model_path):
    model = joblib.load(model_path)
    print("Loaded saved model from:", model_path)
else:
    print("No saved model found – starting fresh.")
# Out:
# No saved model found – starting fresh.
